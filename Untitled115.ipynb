# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import Dropout, AveragePooling2D, concatenate, SeparableConv2D, Conv2D, BatchNormalization, ReLU, UpSampling2D
from tensorflow.keras import backend as K

def expend_as(tensor, rep):
    return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': rep})(tensor)

def gating_signal(input, out_size, batch_norm=False):
    """
    Resize the down layer feature map into the same dimension as the up layer feature map using 1x1 conv.
    :param input: Down-dim feature map.
    :param out_size: Output channel number.
    :param batch_norm: Whether to apply batch normalization.
    :return: The gating feature map with the same dimension as the up layer feature map.
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    theta_x = layers.Conv2D(inter_shape, (1, 1), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

    phi_g = layers.Conv2D(inter_shape, (1, 1), strides=(1, 1),padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([phi_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = expend_as(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn


import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, ReLU, AveragePooling2D, concatenate, UpSampling2D, Conv2D, Dropout, Conv2DTranspose
from tensorflow.keras.initializers import glorot_uniform

class BasicConv(object):
    def __init__(self, out_planes, kernel_size):
        super(BasicConv, self).__init__()
        self.conv = Conv2D(
            out_planes,
            kernel_size=[kernel_size, kernel_size],
            strides=[1, 1],
            padding='same',
            kernel_initializer='glorot_uniform',
            use_bias=False,
            data_format='channels_last')  # Change to channels_last
        self.bn = BatchNormalization(
                axis=-1,
                momentum=0.999,
                epsilon=1e-5,
                fused=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = tf.nn.relu(x)
        return x

class ChannelPool(object):
    def forward(self, x):
        return tf.concat([tf.expand_dims(tf.reduce_max(x, axis=-1), axis=-1),
                          tf.expand_dims(tf.reduce_mean(x, axis=-1), axis=-1)], axis=-1)

class SpatialGate(object):
    def __init__(self):
        super(SpatialGate, self).__init__()
        kernel_size = 3
        self.compress = ChannelPool()
        self.spatial = BasicConv(1, kernel_size)
    def forward(self, x):
        x_compress = self.compress.forward(x)
        x_out = self.spatial.forward(x_compress)
        scale = tf.nn.sigmoid(x_out)
        return x * scale

class TripletAttention(object):
    def __init__(self, reduction_ratio=16, pool_types=['avg', 'max'], no_spatial=False):
        print("Triplet Attention!")
        super(TripletAttention, self).__init__()
        self.ChannelGateH = SpatialGate()
        self.ChannelGateW = SpatialGate()
        self.no_spatial=no_spatial
        if not no_spatial:
            self.SpatialGate = SpatialGate()

    def forward(self, x):
        x_perm1 = tf.transpose(x, perm=[0, 2, 1, 3])
        x_out1 = self.ChannelGateH.forward(x_perm1)
        x_out11 = tf.transpose(x_out1, perm=[0, 2, 1, 3])
        x_perm2 = tf.transpose(x, perm=[0, 3, 2, 1])
        x_out2 = self.ChannelGateW.forward(x_perm2)
        x_out21 = tf.transpose(x_out2, perm=[0, 3, 2, 1])
        if not self.no_spatial:
            x_out = self.SpatialGate.forward(x)
            x_out = (1/3)*(x_out + x_out11 + x_out21)
        else:
            x_out = (1/2)*(x_out11 + x_out21)
        return x_out

def multi_unet_model(n_classes=4, IMG_HEIGHT=480, IMG_WIDTH=480, IMG_CHANNELS=3, use_bilinear_upsampling=True):
    # Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = inputs

    def conv_block(x, filters, kernel_size=3, dilation_rate=1, dropout_rate=0.2):
        conv1 = SeparableConv2D(filters, kernel_size, padding='same', dilation_rate=dilation_rate)(x)
        conv1 = BatchNormalization()(conv1)
        conv1 = ReLU()(conv1)

        conv2 = SeparableConv2D(filters, kernel_size, padding='same', dilation_rate=dilation_rate)(conv1)
        conv2 = BatchNormalization()(conv2)
        conv2 = ReLU()(conv2)

        x = concatenate([conv1, conv2])

        if dropout_rate > 0:
            x = Dropout(dropout_rate)(x)

        return x

    def upsample_block(x, skip, filters, use_bilinear_upsampling, dropout_rate=0.2):
        gating = gating_signal(x, filters, batch_norm=True)
        att = attention_block(skip, gating, filters)
        if use_bilinear_upsampling:
          x = UpSampling2D(size=(2, 2), interpolation='bilinear')(x)
        else:
          x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        x = concatenate([x, att], axis=-1)
        x = conv_block(x, filters, dropout_rate=dropout_rate)
        return x
    def upsample_block2(x, skip, filters, use_bilinear_upsampling, dropout_rate=0.2):
        if use_bilinear_upsampling:
          x = UpSampling2D(size=(2, 2), interpolation='bilinear')(x)
        else:
          x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        x = concatenate([x, skip], axis=-1)
        x = conv_block(x, filters, dropout_rate=dropout_rate)
        return x

    # Contraction path
    c1 = conv_block(s, 32, dilation_rate=1, dropout_rate=0.2)
    p1 = AveragePooling2D((2, 2))(c1)

    c2 = conv_block(p1, 64, dilation_rate=1, dropout_rate=0.2)
    p2 = AveragePooling2D((2, 2))(c2)

    c3 = conv_block(p2, 128, dilation_rate=2, dropout_rate=0.2)
    p3 = AveragePooling2D((2, 2))(c3)

    c4 = conv_block(p3, 256, dilation_rate=2, dropout_rate=0.2)
    p4 = AveragePooling2D((2, 2))(c4)

    c5 = conv_block(p4, 512, dilation_rate=4, dropout_rate=0.3)

    # Expansion path with attention gates
    u6 = upsample_block(c5, c4, 256, use_bilinear_upsampling, dropout_rate=0.2)
    u7 = upsample_block(u6, c3, 128, use_bilinear_upsampling, dropout_rate=0.2)
    u8 = upsample_block(u7, c2, 64, use_bilinear_upsampling, dropout_rate=0.2)

    # Apply Triplet Attention to the skip connection between c1 and u8
    triplet_attention = TripletAttention()
    c1 = triplet_attention.forward(c1)
    print(c1.shape)
    u8 = triplet_attention.forward(u8)
    print(u8.shape)

    u9 = upsample_block2(u8, c1, 32, use_bilinear_upsampling, dropout_rate=0.2)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(u9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# Usage:
model = multi_unet_model()
model.summary()
# Out:
# Triplet Attention!
# (None, 480, 480, 64)
# (None, 240, 240, 128)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 480, 480, 3)]        0         []
#
#  separable_conv2d (Separabl  (None, 480, 480, 32)         155       ['input_1[0][0]']
#  eConv2D)
#
#  batch_normalization (Batch  (None, 480, 480, 32)         128       ['separable_conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 480, 480, 32)         0         ['batch_normalization[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 480, 480, 32)         1344      ['re_lu[0][0]']
#  bleConv2D)
#
#  batch_normalization_1 (Bat  (None, 480, 480, 32)         128       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 480, 480, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 480, 480, 64)         0         ['re_lu[0][0]',
#                                                                      're_lu_1[0][0]']
#
#  dropout (Dropout)           (None, 480, 480, 64)         0         ['concatenate[0][0]']
#
#  average_pooling2d (Average  (None, 240, 240, 64)         0         ['dropout[0][0]']
#  Pooling2D)
#
#  separable_conv2d_2 (Separa  (None, 240, 240, 64)         4736      ['average_pooling2d[0][0]']
#  bleConv2D)
#
#  batch_normalization_2 (Bat  (None, 240, 240, 64)         256       ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 240, 240, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv2d_3 (Separa  (None, 240, 240, 64)         4736      ['re_lu_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_3 (Bat  (None, 240, 240, 64)         256       ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 240, 240, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 240, 240, 128)        0         ['re_lu_2[0][0]',
#  )                                                                   're_lu_3[0][0]']
#
#  dropout_1 (Dropout)         (None, 240, 240, 128)        0         ['concatenate_1[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 120, 120, 128)        0         ['dropout_1[0][0]']
#  gePooling2D)
#
#  separable_conv2d_4 (Separa  (None, 120, 120, 128)        17664     ['average_pooling2d_1[0][0]']
#  bleConv2D)
#
#  batch_normalization_4 (Bat  (None, 120, 120, 128)        512       ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 120, 120, 128)        0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  separable_conv2d_5 (Separa  (None, 120, 120, 128)        17664     ['re_lu_4[0][0]']
#  bleConv2D)
#
#  batch_normalization_5 (Bat  (None, 120, 120, 128)        512       ['separable_conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 120, 120, 128)        0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 120, 120, 256)        0         ['re_lu_4[0][0]',
#  )                                                                   're_lu_5[0][0]']
#
#  dropout_2 (Dropout)         (None, 120, 120, 256)        0         ['concatenate_2[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 60, 60, 256)          0         ['dropout_2[0][0]']
#  gePooling2D)
#
#  separable_conv2d_6 (Separa  (None, 60, 60, 256)          68096     ['average_pooling2d_2[0][0]']
#  bleConv2D)
#
#  batch_normalization_6 (Bat  (None, 60, 60, 256)          1024      ['separable_conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 60, 60, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  separable_conv2d_7 (Separa  (None, 60, 60, 256)          68096     ['re_lu_6[0][0]']
#  bleConv2D)
#
#  batch_normalization_7 (Bat  (None, 60, 60, 256)          1024      ['separable_conv2d_7[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 60, 60, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate_3 (Concatenate  (None, 60, 60, 512)          0         ['re_lu_6[0][0]',
#  )                                                                   're_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 60, 60, 512)          0         ['concatenate_3[0][0]']
#
#  average_pooling2d_3 (Avera  (None, 30, 30, 512)          0         ['dropout_3[0][0]']
#  gePooling2D)
#
#  separable_conv2d_8 (Separa  (None, 30, 30, 512)          267264    ['average_pooling2d_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_8 (Bat  (None, 30, 30, 512)          2048      ['separable_conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 30, 30, 512)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv2d_9 (Separa  (None, 30, 30, 512)          267264    ['re_lu_8[0][0]']
#  bleConv2D)
#
#  batch_normalization_9 (Bat  (None, 30, 30, 512)          2048      ['separable_conv2d_9[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 30, 30, 512)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate_4 (Concatenate  (None, 30, 30, 1024)         0         ['re_lu_8[0][0]',
#  )                                                                   're_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 30, 30, 1024)         0         ['concatenate_4[0][0]']
#
#  conv2d (Conv2D)             (None, 30, 30, 256)          262400    ['dropout_4[0][0]']
#
#  batch_normalization_10 (Ba  (None, 30, 30, 256)          1024      ['conv2d[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 30, 30, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 256)          65792     ['activation[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 256)          131328    ['dropout_3[0][0]']
#
#  add (Add)                   (None, 30, 30, 256)          0         ['conv2d_2[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  activation_1 (Activation)   (None, 30, 30, 256)          0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 30, 30, 1)            257       ['activation_1[0][0]']
#
#  activation_2 (Activation)   (None, 30, 30, 1)            0         ['conv2d_3[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 60, 60, 1)            0         ['activation_2[0][0]']
#  D)
#
#  lambda (Lambda)             (None, 60, 60, 512)          0         ['up_sampling2d[0][0]']
#
#  multiply (Multiply)         (None, 60, 60, 512)          0         ['lambda[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 512)          262656    ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 60, 60, 1024)         0         ['dropout_4[0][0]']
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 60, 60, 512)          2048      ['conv2d_4[0][0]']
#  tchNormalization)
#
#  concatenate_5 (Concatenate  (None, 60, 60, 1536)         0         ['up_sampling2d_1[0][0]',
#  )                                                                   'batch_normalization_11[0][0]
#                                                                     ']
#
#  separable_conv2d_10 (Separ  (None, 60, 60, 256)          407296    ['concatenate_5[0][0]']
#  ableConv2D)
#
#  batch_normalization_12 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_10[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  separable_conv2d_11 (Separ  (None, 60, 60, 256)          68096     ['re_lu_10[0][0]']
#  ableConv2D)
#
#  batch_normalization_13 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 60, 60, 512)          0         ['re_lu_10[0][0]',
#  )                                                                   're_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 60, 60, 512)          0         ['concatenate_6[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 128)          65664     ['dropout_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, 60, 60, 128)          512       ['conv2d_5[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 60, 60, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 60, 60, 128)          16512     ['activation_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 60, 60, 128)          32896     ['dropout_2[0][0]']
#
#  add_1 (Add)                 (None, 60, 60, 128)          0         ['conv2d_7[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  activation_4 (Activation)   (None, 60, 60, 128)          0         ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 1)            129       ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 60, 60, 1)            0         ['conv2d_8[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 120, 120, 1)          0         ['activation_5[0][0]']
#  g2D)
#
#  lambda_1 (Lambda)           (None, 120, 120, 256)        0         ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)       (None, 120, 120, 256)        0         ['lambda_1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 120, 120, 256)        65792     ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 120, 120, 512)        0         ['dropout_5[0][0]']
#  g2D)
#
#  batch_normalization_15 (Ba  (None, 120, 120, 256)        1024      ['conv2d_9[0][0]']
#  tchNormalization)
#
#  concatenate_7 (Concatenate  (None, 120, 120, 768)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'batch_normalization_15[0][0]
#                                                                     ']
#
#  separable_conv2d_12 (Separ  (None, 120, 120, 128)        105344    ['concatenate_7[0][0]']
#  ableConv2D)
#
#  batch_normalization_16 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_12[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  separable_conv2d_13 (Separ  (None, 120, 120, 128)        17664     ['re_lu_12[0][0]']
#  ableConv2D)
#
#  batch_normalization_17 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  concatenate_8 (Concatenate  (None, 120, 120, 256)        0         ['re_lu_12[0][0]',
#  )                                                                   're_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 120, 120, 256)        0         ['concatenate_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 120, 120, 64)         16448     ['dropout_6[0][0]']
#
#  batch_normalization_18 (Ba  (None, 120, 120, 64)         256       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 120, 120, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 120, 120, 64)         4160      ['activation_6[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 120, 120, 64)         8256      ['dropout_1[0][0]']
#
#  add_2 (Add)                 (None, 120, 120, 64)         0         ['conv2d_12[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_7 (Activation)   (None, 120, 120, 64)         0         ['add_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 120, 120, 1)          65        ['activation_7[0][0]']
#
#  activation_8 (Activation)   (None, 120, 120, 1)          0         ['conv2d_13[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 240, 240, 1)          0         ['activation_8[0][0]']
#  g2D)
#
#  lambda_2 (Lambda)           (None, 240, 240, 128)        0         ['up_sampling2d_4[0][0]']
#
#  multiply_2 (Multiply)       (None, 240, 240, 128)        0         ['lambda_2[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 240, 240, 128)        16512     ['multiply_2[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 240, 240, 256)        0         ['dropout_6[0][0]']
#  g2D)
#
#  batch_normalization_19 (Ba  (None, 240, 240, 128)        512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  concatenate_9 (Concatenate  (None, 240, 240, 384)        0         ['up_sampling2d_5[0][0]',
#  )                                                                   'batch_normalization_19[0][0]
#                                                                     ']
#
#  separable_conv2d_14 (Separ  (None, 240, 240, 64)         28096     ['concatenate_9[0][0]']
#  ableConv2D)
#
#  batch_normalization_20 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_14[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  separable_conv2d_15 (Separ  (None, 240, 240, 64)         4736      ['re_lu_14[0][0]']
#  ableConv2D)
#
#  batch_normalization_21 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 240, 240, 128)        0         ['re_lu_14[0][0]',
#  e)                                                                  're_lu_15[0][0]']
#
#  dropout_7 (Dropout)         (None, 240, 240, 128)        0         ['concatenate_10[0][0]']
#
#  tf.compat.v1.transpose_4 (  (None, 240, 240, 128)        0         ['dropout_7[0][0]']
#  TFOpLambda)
#
#  tf.math.reduce_max_3 (TFOp  (None, 240, 240)             0         ['tf.compat.v1.transpose_4[0][
#  Lambda)                                                            0]']
#
#  tf.math.reduce_mean_3 (TFO  (None, 240, 240)             0         ['tf.compat.v1.transpose_4[0][
#  pLambda)                                                           0]']
#
#  tf.compat.v1.transpose_6 (  (None, 128, 240, 240)        0         ['dropout_7[0][0]']
#  TFOpLambda)
#
#  tf.compat.v1.transpose (TF  (None, 480, 480, 64)         0         ['dropout[0][0]']
#  OpLambda)
#
#  tf.math.reduce_max_5 (TFOp  (None, 240, 240)             0         ['dropout_7[0][0]']
#  Lambda)
#
#  tf.math.reduce_mean_5 (TFO  (None, 240, 240)             0         ['dropout_7[0][0]']
#  pLambda)
#
#  tf.expand_dims_6 (TFOpLamb  (None, 240, 240, 1)          0         ['tf.math.reduce_max_3[0][0]']
#  da)
#
#  tf.expand_dims_7 (TFOpLamb  (None, 240, 240, 1)          0         ['tf.math.reduce_mean_3[0][0]'
#  da)                                                                ]
#
#  tf.math.reduce_max_4 (TFOp  (None, 128, 240)             0         ['tf.compat.v1.transpose_6[0][
#  Lambda)                                                            0]']
#
#  tf.math.reduce_mean_4 (TFO  (None, 128, 240)             0         ['tf.compat.v1.transpose_6[0][
#  pLambda)                                                           0]']
#
#  tf.math.reduce_max (TFOpLa  (None, 480, 480)             0         ['tf.compat.v1.transpose[0][0]
#  mbda)                                                              ']
#
#  tf.math.reduce_mean (TFOpL  (None, 480, 480)             0         ['tf.compat.v1.transpose[0][0]
#  ambda)                                                             ']
#
#  tf.compat.v1.transpose_2 (  (None, 64, 480, 480)         0         ['dropout[0][0]']
#  TFOpLambda)
#
#  tf.expand_dims_10 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_max_5[0][0]']
#  bda)
#
#  tf.expand_dims_11 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_mean_5[0][0]'
#  bda)                                                               ]
#
#  tf.concat_3 (TFOpLambda)    (None, 240, 240, 2)          0         ['tf.expand_dims_6[0][0]',
#                                                                      'tf.expand_dims_7[0][0]']
#
#  tf.expand_dims_8 (TFOpLamb  (None, 128, 240, 1)          0         ['tf.math.reduce_max_4[0][0]']
#  da)
#
#  tf.expand_dims_9 (TFOpLamb  (None, 128, 240, 1)          0         ['tf.math.reduce_mean_4[0][0]'
#  da)                                                                ]
#
#  tf.math.reduce_max_2 (TFOp  (None, 480, 480)             0         ['dropout[0][0]']
#  Lambda)
#
#  tf.math.reduce_mean_2 (TFO  (None, 480, 480)             0         ['dropout[0][0]']
#  pLambda)
#
#  tf.expand_dims (TFOpLambda  (None, 480, 480, 1)          0         ['tf.math.reduce_max[0][0]']
#  )
#
#  tf.expand_dims_1 (TFOpLamb  (None, 480, 480, 1)          0         ['tf.math.reduce_mean[0][0]']
#  da)
#
#  tf.math.reduce_max_1 (TFOp  (None, 64, 480)              0         ['tf.compat.v1.transpose_2[0][
#  Lambda)                                                            0]']
#
#  tf.math.reduce_mean_1 (TFO  (None, 64, 480)              0         ['tf.compat.v1.transpose_2[0][
#  pLambda)                                                           0]']
#
#  tf.concat_5 (TFOpLambda)    (None, 240, 240, 2)          0         ['tf.expand_dims_10[0][0]',
#                                                                      'tf.expand_dims_11[0][0]']
#
#  conv2d_15 (Conv2D)          multiple                     18        ['tf.concat[0][0]',
#                                                                      'tf.concat_3[0][0]']
#
#  tf.concat_4 (TFOpLambda)    (None, 128, 240, 2)          0         ['tf.expand_dims_8[0][0]',
#                                                                      'tf.expand_dims_9[0][0]']
#
#  tf.expand_dims_4 (TFOpLamb  (None, 480, 480, 1)          0         ['tf.math.reduce_max_2[0][0]']
#  da)
#
#  tf.expand_dims_5 (TFOpLamb  (None, 480, 480, 1)          0         ['tf.math.reduce_mean_2[0][0]'
#  da)                                                                ]
#
#  tf.concat (TFOpLambda)      (None, 480, 480, 2)          0         ['tf.expand_dims[0][0]',
#                                                                      'tf.expand_dims_1[0][0]']
#
#  tf.expand_dims_2 (TFOpLamb  (None, 64, 480, 1)           0         ['tf.math.reduce_max_1[0][0]']
#  da)
#
#  tf.expand_dims_3 (TFOpLamb  (None, 64, 480, 1)           0         ['tf.math.reduce_mean_1[0][0]'
#  da)                                                                ]
#
#  conv2d_17 (Conv2D)          multiple                     18        ['tf.concat_2[0][0]',
#                                                                      'tf.concat_5[0][0]']
#
#  batch_normalization_22 (Ba  multiple                     4         ['conv2d_15[0][0]',
#  tchNormalization)                                                   'conv2d_15[1][0]']
#
#  conv2d_16 (Conv2D)          multiple                     18        ['tf.concat_1[0][0]',
#                                                                      'tf.concat_4[0][0]']
#
#  tf.concat_2 (TFOpLambda)    (None, 480, 480, 2)          0         ['tf.expand_dims_4[0][0]',
#                                                                      'tf.expand_dims_5[0][0]']
#
#  tf.concat_1 (TFOpLambda)    (None, 64, 480, 2)           0         ['tf.expand_dims_2[0][0]',
#                                                                      'tf.expand_dims_3[0][0]']
#
#  batch_normalization_24 (Ba  multiple                     4         ['conv2d_17[0][0]',
#  tchNormalization)                                                   'conv2d_17[1][0]']
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 240, 240, 1)          0         ['batch_normalization_22[1][0]
#                                                                     ']
#
#  batch_normalization_23 (Ba  multiple                     4         ['conv2d_16[0][0]',
#  tchNormalization)                                                   'conv2d_16[1][0]']
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 240, 240, 1)          0         ['batch_normalization_24[1][0]
#                                                                     ']
#
#  tf.math.sigmoid_3 (TFOpLam  (None, 240, 240, 1)          0         ['tf.nn.relu_3[0][0]']
#  bda)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 128, 240, 1)          0         ['batch_normalization_23[1][0]
#                                                                     ']
#
#  tf.nn.relu (TFOpLambda)     (None, 480, 480, 1)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  tf.math.sigmoid_5 (TFOpLam  (None, 240, 240, 1)          0         ['tf.nn.relu_5[0][0]']
#  bda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 240, 240, 128)        0         ['tf.compat.v1.transpose_4[0][
#  mbda)                                                              0]',
#                                                                      'tf.math.sigmoid_3[0][0]']
#
#  tf.math.sigmoid_4 (TFOpLam  (None, 128, 240, 1)          0         ['tf.nn.relu_4[0][0]']
#  bda)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 480, 480, 1)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  tf.math.sigmoid (TFOpLambd  (None, 480, 480, 1)          0         ['tf.nn.relu[0][0]']
#  a)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 64, 480, 1)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  tf.math.multiply_6 (TFOpLa  (None, 240, 240, 128)        0         ['dropout_7[0][0]',
#  mbda)                                                               'tf.math.sigmoid_5[0][0]']
#
#  tf.compat.v1.transpose_5 (  (None, 240, 240, 128)        0         ['tf.math.multiply_4[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_5 (TFOpLa  (None, 128, 240, 240)        0         ['tf.compat.v1.transpose_6[0][
#  mbda)                                                              0]',
#                                                                      'tf.math.sigmoid_4[0][0]']
#
#  tf.math.sigmoid_2 (TFOpLam  (None, 480, 480, 1)          0         ['tf.nn.relu_2[0][0]']
#  bda)
#
#  tf.math.multiply (TFOpLamb  (None, 480, 480, 64)         0         ['tf.compat.v1.transpose[0][0]
#  da)                                                                ',
#                                                                      'tf.math.sigmoid[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLam  (None, 64, 480, 1)           0         ['tf.nn.relu_1[0][0]']
#  bda)
#
#  tf.__operators__.add_2 (TF  (None, 240, 240, 128)        0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  tf.compat.v1.transpose_7 (  (None, 240, 240, 128)        0         ['tf.math.multiply_5[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_2 (TFOpLa  (None, 480, 480, 64)         0         ['dropout[0][0]',
#  mbda)                                                               'tf.math.sigmoid_2[0][0]']
#
#  tf.compat.v1.transpose_1 (  (None, 480, 480, 64)         0         ['tf.math.multiply[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_1 (TFOpLa  (None, 64, 480, 480)         0         ['tf.compat.v1.transpose_2[0][
#  mbda)                                                              0]',
#                                                                      'tf.math.sigmoid_1[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 240, 240, 128)        0         ['tf.__operators__.add_2[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  tf.__operators__.add (TFOp  (None, 480, 480, 64)         0         ['tf.math.multiply_2[0][0]',
#  Lambda)                                                             'tf.compat.v1.transpose_1[0][
#                                                                     0]']
#
#  tf.compat.v1.transpose_3 (  (None, 480, 480, 64)         0         ['tf.math.multiply_1[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_7 (TFOpLa  (None, 240, 240, 128)        0         ['tf.__operators__.add_3[0][0]
#  mbda)                                                              ']
#
#  tf.__operators__.add_1 (TF  (None, 480, 480, 64)         0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 480, 480, 128)        0         ['tf.math.multiply_7[0][0]']
#  g2D)
#
#  tf.math.multiply_3 (TFOpLa  (None, 480, 480, 64)         0         ['tf.__operators__.add_1[0][0]
#  mbda)                                                              ']
#
#  concatenate_11 (Concatenat  (None, 480, 480, 192)        0         ['up_sampling2d_6[0][0]',
#  e)                                                                  'tf.math.multiply_3[0][0]']
#
#  separable_conv2d_16 (Separ  (None, 480, 480, 32)         7904      ['concatenate_11[0][0]']
#  ableConv2D)
#
#  batch_normalization_25 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  separable_conv2d_17 (Separ  (None, 480, 480, 32)         1344      ['re_lu_16[0][0]']
#  ableConv2D)
#
#  batch_normalization_26 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_17[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  concatenate_12 (Concatenat  (None, 480, 480, 64)         0         ['re_lu_16[0][0]',
#  e)                                                                  're_lu_17[0][0]']
#
#  dropout_8 (Dropout)         (None, 480, 480, 64)         0         ['concatenate_12[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 480, 480, 4)          260       ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 2323844 (8.86 MB)
# Trainable params: 2315262 (8.83 MB)
# Non-trainable params: 8582 (33.52 KB)
# __________________________________________________________________________________________________

# %%
# !pip install patchify
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.25.2)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
# !pip install segmentation_models
# Out:
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.7 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.6.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (24.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import cv2
import numpy as np

from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
root_directory = '/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train'

patch_size = 480

# %%
# Verify the image path is correct and the file exists
image_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/images/NITR_AC_JAN26_29.png"
if not os.path.exists(image_path):
    print(f"Error: Image file not found at {image_path}")
else:
    temp_img = cv2.imread(image_path) #3 channels / spectral bands
    if temp_img is None:
        print(f"Error: Failed to load image from {image_path}. Check file format and permissions.")
    else:
        plt.imshow(temp_img[:,:,2]) #View each channel...
        temp_mask = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/gray_masks/NITR_AC_JAN26_29.png") #3 channels but all same.
        labels, count = np.unique(temp_mask[:,:,0], return_counts=True) #Check for each channel. All chanels are identical
        print("Labels are: ", labels, " and the counts are: ", count)
# Out:
# Labels are:  [0 1 2 3]  and the counts are:  [5288202 3926480  249443 2535875]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# File paths
image_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/images/NITR_AC_JAN26_29.png"
mask_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/gray_masks/NITR_AC_JAN26_29.png"

# Read the image (3 channels / spectral bands)
temp_img = cv2.imread(image_path)
if temp_img is None:
    raise FileNotFoundError(f"Image file not found at {image_path}")

# Convert from BGR to RGB for display
temp_img_rgb = cv2.cvtColor(temp_img, cv2.COLOR_BGR2RGB)

# Display the third channel
plt.imshow(temp_img_rgb[:,:,2])
plt.title('Third Channel of the Image')
plt.show()

# Read the mask (3 channels but all are the same)
temp_mask = cv2.imread(mask_path, cv2.COLOR_BGR2RGB)
if temp_mask is None:
    raise FileNotFoundError(f"Mask file not found at {mask_path}")

# Check the unique labels and their counts in the mask
labels, counts = np.unique(temp_mask, return_counts=True)
print("Labels are: ", labels, " and the counts are: ", counts)
plt.imshow(temp_mask[:,:,])
plt.show()
# Out:
# Labels are:  [0 1 2 3]  and the counts are:  [5288202 3926480  249443 2535875]

# %%
root_directory = '/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/'

patch_size = 480

#Read images from repsective 'images' subdirectory
#As all images are of different size we have 2 options, either resize or crop
#But, some images are too large and some small. Resizing will change the size of real objects.
#Therefore, we will crop them to a nearest size divisible by 256 and then
#divide all images into patches of 480x480x3.

patch_dir = root_directory + "480_patches/images/"
os.makedirs(patch_dir, exist_ok=True)
img_dir=root_directory+"images/"
for path, subdirs, files in os.walk(img_dir):
    #print(path)
    dirname = path.split(os.path.sep)[-1]
    #print(dirname)
    images = os.listdir(path)  #List of all image names in this subdirectory
    # print(images)
    for i, image_name in enumerate(images):
        if image_name.endswith(".png"):
            print(image_name)
            image_path = os.path.join(path, image_name)
            image = cv2.imread(image_path, 1)  #Read each image as BGR

            if image is None:
                print(f"Error reading image {image_path}")
                continue

            SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
            SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
            image = Image.fromarray(image)
            image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
            #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
            image = np.array(image)

            #Extract patches from each image
            # print("Now patchifying image:", image_path)
            patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap

            for i in range(patches_img.shape[0]):
                for j in range(patches_img.shape[1]):

                    single_patch_img = patches_img[i,j,:,:]
                    #single_patch_img = (single_patch_img.astype('float32')) / 255. #We will preprocess using one of the backbones
                    single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.
                    patch_name = f"{image_name}patch_{i}{j}.png"
                    patch_path = os.path.join(patch_dir, patch_name)
                    cv2.imwrite(patch_path, single_patch_img)
                    print(f"Saved patch: {patch_path}")


                    # cv2.imwrite(root_directory+"480_patches/images/"+
                    #            image_name+"patch_"+str(i)+str(j)+".png", single_patch_img)
                    #image_dataset.append(single_patch_img)
# Out:
# NITR_AC_JAN26_29.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_37.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_40.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_41.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_42.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_43.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_44.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_45.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_46.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_47.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_50.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_51.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_52.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_53.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_54.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_55.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_56.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_29.pngpatch_57.png
# NITR_AC_JAN26_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_37.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_40.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_41.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_42.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_43.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_44.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_45.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_46.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_47.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_50.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_51.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_52.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_53.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_54.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_55.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_56.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_30.pngpatch_57.png
# NITR_AC_JAN26_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_37.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_40.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_41.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_42.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_43.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_44.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_45.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_46.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_47.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_50.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_51.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_52.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_53.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_54.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_55.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_56.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_32.pngpatch_57.png
# NITR_AC_JAN26_28.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_37.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_40.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_41.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_42.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_43.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_44.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_45.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_46.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_47.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_50.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_51.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_52.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_53.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_54.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_55.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_56.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_JAN26_28.pngpatch_57.png
# NITR_AC_P_89.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_89.pngpatch_37.png
# NITR_AC_P_90.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_00.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_01.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_02.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_03.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_04.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_05.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_06.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_07.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_10.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_11.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_12.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_13.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_14.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_15.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_16.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_17.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_20.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_21.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_22.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_23.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_24.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_25.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_26.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_27.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_30.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_31.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_32.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_33.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_34.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_35.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_36.png
# Saved patch: /content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/NITR_AC_P_90.pngpatch_37.png

# %%
import os
import cv2
import numpy as np
from patchify import patchify
from PIL import Image

root_directory = '/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/'
patch_size = 480

# Create directories for saving patches if they don't exist
mask_patch_dir = os.path.join(root_directory, "480_patches", "masks")
os.makedirs(mask_patch_dir, exist_ok=True)

mask_dir = os.path.join(root_directory, "gray_masks")
for path, subdirs, files in os.walk(mask_dir):
    masks = os.listdir(path)  # List of all mask names in this subdirectory

    for mask_name in masks:
        if mask_name.endswith(".png"):
            mask_path = os.path.join(path, mask_name)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read each image as Grayscale

            if mask is None:
                print(f"Error reading mask {mask_path}")
                continue

            SIZE_X = (mask.shape[1] // patch_size) * patch_size  # Nearest size divisible by our patch size
            SIZE_Y = (mask.shape[0] // patch_size) * patch_size  # Nearest size divisible by our patch size

            mask = Image.fromarray(mask)
            mask = mask.crop((0, 0, SIZE_X, SIZE_Y))  # Crop from top left corner
            mask = np.array(mask)

            # Extract patches from each mask
            print("Now patchifying mask:", mask_path)
            patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  # Step=patch_size means no overlap

            for i in range(patches_mask.shape[0]):
                for j in range(patches_mask.shape[1]):
                    single_patch_mask = patches_mask[i, j, :, :]  # Drop the extra unnecessary dimension that patchify adds
                    patch_name = f"{mask_name}patch_{i}{j}.png"
                    patch_path = os.path.join(mask_patch_dir, patch_name)

                    # Write the patch mask to the specified directory
                    cv2.imwrite(patch_path, single_patch_mask)
                    print(f"Saved mask patch: {patch_path}")

# %%
train_img_dir = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images/"
train_mask_dir ="/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/masks/"

import random
seed = 42
img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)
img_list.sort()
msk_list.sort()
print(len(img_list), len(msk_list))

num_images = len(os.listdir(train_mask_dir))


img_num = random.randint(0, num_images-1)
print(img_num)
img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)
print(img_list[img_num],msk_list[img_num])
mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
# Out:
# 256 256
# 107
# NITR_AC_JAN26_30.pngpatch_13.png NITR_AC_JAN26_30.pngpatch_13.png
# Text(0.5, 1.0, 'Mask')

# %%
#Now, let us copy images and masks with real information to a new folder.
# real information = if mask has decent amount of labels other than 0.
patch_dir = root_directory + "480_patches/images_with_useful_info/images/"
os.makedirs(patch_dir, exist_ok=True)
patch_dir = root_directory + "480_patches/images_with_useful_info/masks/"
os.makedirs(patch_dir, exist_ok=True)

useless=0  #Useless image counter
for img in range(len(img_list)):   #Using t1_list as all lists are of same size
    img_name=img_list[img]
    mask_name = msk_list[img]
    # print("Now preparing image and masks number: "+ img_name, img)
    # print("Now preparing image and masks number: "+ mask_name)


    temp_image=cv2.imread(train_img_dir+img_list[img], 1)

    temp_mask=cv2.imread(train_mask_dir+msk_list[img], 0)
    #temp_mask=temp_mask.astype(np.uint8)

    val, counts = np.unique(temp_mask, return_counts=True)

    if (1 - (counts[0]/counts.sum())) > 0.05:  #At least 5% useful area with labels that are not 0
        # continue
        print("Save Me")
        cv2.imwrite('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images_with_useful_info/images/'+img_name, temp_image)
        cv2.imwrite('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images_with_useful_info/masks/'+mask_name, temp_mask)
    else:
        # print("I am useless")
        useless +=1

# %%
print("Total useful images are: ", len(img_list)-useless)  #20,075
print("Total useless images are: ", useless) #21,571
# Out:
# Total useful images are:  123
# Total useless images are:  0

# %%
pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders  # or import split_folders

input_folder = '/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/480_patches/images_with_useful_info'
output_folder = '/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_training_and_testing/'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values

# %%
train_img_dir = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/train_images/train/"
train_mask_dir = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/train_masks/train/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)
img_list.sort() # Use the sort() method to sort the list in place
msk_list.sort()
print(len(img_list), len(msk_list))

num_images = len(os.listdir(train_img_dir))
seed=42

img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()
# Out:
# 123 123

# %%
seed=24
batch_size= 4
n_classes=4

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from keras.utils import to_categorical

#Use this to preprocess input for transfer learning
BACKBONE = 'resnet34'
preprocess_input = sm.get_preprocessing(BACKBONE)

#Define a function to perform additional preprocessing after datagen.
#For example, scale images, convert masks to categorical, etc.
def preprocess_data(img, mask, num_class):
    #Scale images
    scaler = MinMaxScaler() # Initialize scaler outside the loop
    scaler.fit(img.reshape(-1, img.shape[-1])) # Fit the scaler once
    img = scaler.transform(img.reshape(-1, img.shape[-1])).reshape(img.shape) # Transform the image

    img = scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)
    img = preprocess_input(img)  #Preprocess based on the pretrained backbone...
    #Convert mask to one-hot
    mask = to_categorical(mask, num_class)

    return (img,mask)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
def trainGenerator(train_img_path, train_mask_path, num_class):

    img_data_gen_args = dict(horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect')

    image_datagen = ImageDataGenerator(**img_data_gen_args)
    mask_datagen = ImageDataGenerator(**img_data_gen_args)

    image_generator = image_datagen.flow_from_directory(
        train_img_path,
        target_size=(480, 480),  # Set target size to 480x480
        class_mode = None,
        batch_size = batch_size,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_mask_path,
        target_size=(480, 480),  # Set target size to 480x480
        class_mode = None,
        color_mode = 'grayscale',
        batch_size = batch_size,
        seed = seed)

    train_generator = zip(image_generator, mask_generator)

    for (img, mask) in train_generator:
        # print(img)
        img, mask = preprocess_data(img, mask, num_class)
        yield (img, mask)

# %%
train_img_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/train_images/"
train_mask_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/train_masks/"
train_img_gen = trainGenerator(train_img_path, train_mask_path, num_class=4)

val_img_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/val_images/"
val_mask_path = "/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/val_masks/"
val_img_gen = trainGenerator(val_img_path, val_mask_path, num_class=4)

# %%
x, y = train_img_gen.__next__()
x.shape, y.shape
# Out:
# Found 123 images belonging to 1 classes.
# Found 123 images belonging to 1 classes.
# ((4, 480, 480, 3), (4, 480, 480, 4))

# %%
for i in range(0,3):
    image = x[i]
    mask = np.argmax(y[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()

x_val, y_val = val_img_gen.__next__()

for i in range(0,3):
    image = x_val[i]
    mask = np.argmax(y_val[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()
# Out:
# Found 42 images belonging to 1 classes.
# Found 42 images belonging to 1 classes.

# %%
num_train_imgs = len(os.listdir('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/train_images/train/'))
num_val_images = len(os.listdir('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/train/data_for_keras_aug/val_images/val/'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size


IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]
n_classes=4

# %%
def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)
metrics=['accuracy', jacard_coef]
model = get_model()
# model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
# model.compile(optimizer='adam', loss='categorical_focal_loss', metrics=metrics
model.summary()

print(model.input_shape)
# Out:
# Triplet Attention!
# (None, 480, 480, 64)
# (None, 240, 240, 128)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 480, 480, 3)]        0         []
#
#  separable_conv2d_18 (Separ  (None, 480, 480, 32)         155       ['input_2[0][0]']
#  ableConv2D)
#
#  batch_normalization_27 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  separable_conv2d_19 (Separ  (None, 480, 480, 32)         1344      ['re_lu_18[0][0]']
#  ableConv2D)
#
#  batch_normalization_28 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  concatenate_13 (Concatenat  (None, 480, 480, 64)         0         ['re_lu_18[0][0]',
#  e)                                                                  're_lu_19[0][0]']
#
#  dropout_9 (Dropout)         (None, 480, 480, 64)         0         ['concatenate_13[0][0]']
#
#  average_pooling2d_4 (Avera  (None, 240, 240, 64)         0         ['dropout_9[0][0]']
#  gePooling2D)
#
#  separable_conv2d_20 (Separ  (None, 240, 240, 64)         4736      ['average_pooling2d_4[0][0]']
#  ableConv2D)
#
#  batch_normalization_29 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_20[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  separable_conv2d_21 (Separ  (None, 240, 240, 64)         4736      ['re_lu_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_30 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  concatenate_14 (Concatenat  (None, 240, 240, 128)        0         ['re_lu_20[0][0]',
#  e)                                                                  're_lu_21[0][0]']
#
#  dropout_10 (Dropout)        (None, 240, 240, 128)        0         ['concatenate_14[0][0]']
#
#  average_pooling2d_5 (Avera  (None, 120, 120, 128)        0         ['dropout_10[0][0]']
#  gePooling2D)
#
#  separable_conv2d_22 (Separ  (None, 120, 120, 128)        17664     ['average_pooling2d_5[0][0]']
#  ableConv2D)
#
#  batch_normalization_31 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  separable_conv2d_23 (Separ  (None, 120, 120, 128)        17664     ['re_lu_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_32 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_23[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 120, 120, 256)        0         ['re_lu_22[0][0]',
#  e)                                                                  're_lu_23[0][0]']
#
#  dropout_11 (Dropout)        (None, 120, 120, 256)        0         ['concatenate_15[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 60, 60, 256)          0         ['dropout_11[0][0]']
#  gePooling2D)
#
#  separable_conv2d_24 (Separ  (None, 60, 60, 256)          68096     ['average_pooling2d_6[0][0]']
#  ableConv2D)
#
#  batch_normalization_33 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  separable_conv2d_25 (Separ  (None, 60, 60, 256)          68096     ['re_lu_24[0][0]']
#  ableConv2D)
#
#  batch_normalization_34 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  concatenate_16 (Concatenat  (None, 60, 60, 512)          0         ['re_lu_24[0][0]',
#  e)                                                                  're_lu_25[0][0]']
#
#  dropout_12 (Dropout)        (None, 60, 60, 512)          0         ['concatenate_16[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 30, 30, 512)          0         ['dropout_12[0][0]']
#  gePooling2D)
#
#  separable_conv2d_26 (Separ  (None, 30, 30, 512)          267264    ['average_pooling2d_7[0][0]']
#  ableConv2D)
#
#  batch_normalization_35 (Ba  (None, 30, 30, 512)          2048      ['separable_conv2d_26[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 30, 30, 512)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  separable_conv2d_27 (Separ  (None, 30, 30, 512)          267264    ['re_lu_26[0][0]']
#  ableConv2D)
#
#  batch_normalization_36 (Ba  (None, 30, 30, 512)          2048      ['separable_conv2d_27[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 30, 30, 512)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  concatenate_17 (Concatenat  (None, 30, 30, 1024)         0         ['re_lu_26[0][0]',
#  e)                                                                  're_lu_27[0][0]']
#
#  dropout_13 (Dropout)        (None, 30, 30, 1024)         0         ['concatenate_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 30, 30, 256)          262400    ['dropout_13[0][0]']
#
#  batch_normalization_37 (Ba  (None, 30, 30, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 30, 30, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 30, 30, 256)          65792     ['activation_9[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 30, 30, 256)          131328    ['dropout_12[0][0]']
#
#  add_3 (Add)                 (None, 30, 30, 256)          0         ['conv2d_21[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  activation_10 (Activation)  (None, 30, 30, 256)          0         ['add_3[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 30, 30, 1)            257       ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 30, 30, 1)            0         ['conv2d_22[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 60, 60, 1)            0         ['activation_11[0][0]']
#  g2D)
#
#  lambda_3 (Lambda)           (None, 60, 60, 512)          0         ['up_sampling2d_7[0][0]']
#
#  multiply_3 (Multiply)       (None, 60, 60, 512)          0         ['lambda_3[0][0]',
#                                                                      'dropout_12[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 60, 60, 512)          262656    ['multiply_3[0][0]']
#
#  up_sampling2d_8 (UpSamplin  (None, 60, 60, 1024)         0         ['dropout_13[0][0]']
#  g2D)
#
#  batch_normalization_38 (Ba  (None, 60, 60, 512)          2048      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  concatenate_18 (Concatenat  (None, 60, 60, 1536)         0         ['up_sampling2d_8[0][0]',
#  e)                                                                  'batch_normalization_38[0][0]
#                                                                     ']
#
#  separable_conv2d_28 (Separ  (None, 60, 60, 256)          407296    ['concatenate_18[0][0]']
#  ableConv2D)
#
#  batch_normalization_39 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  separable_conv2d_29 (Separ  (None, 60, 60, 256)          68096     ['re_lu_28[0][0]']
#  ableConv2D)
#
#  batch_normalization_40 (Ba  (None, 60, 60, 256)          1024      ['separable_conv2d_29[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 60, 60, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  concatenate_19 (Concatenat  (None, 60, 60, 512)          0         ['re_lu_28[0][0]',
#  e)                                                                  're_lu_29[0][0]']
#
#  dropout_14 (Dropout)        (None, 60, 60, 512)          0         ['concatenate_19[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 60, 60, 128)          65664     ['dropout_14[0][0]']
#
#  batch_normalization_41 (Ba  (None, 60, 60, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 60, 60, 128)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 60, 60, 128)          16512     ['activation_12[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 60, 60, 128)          32896     ['dropout_11[0][0]']
#
#  add_4 (Add)                 (None, 60, 60, 128)          0         ['conv2d_26[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  activation_13 (Activation)  (None, 60, 60, 128)          0         ['add_4[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 60, 60, 1)            129       ['activation_13[0][0]']
#
#  activation_14 (Activation)  (None, 60, 60, 1)            0         ['conv2d_27[0][0]']
#
#  up_sampling2d_9 (UpSamplin  (None, 120, 120, 1)          0         ['activation_14[0][0]']
#  g2D)
#
#  lambda_4 (Lambda)           (None, 120, 120, 256)        0         ['up_sampling2d_9[0][0]']
#
#  multiply_4 (Multiply)       (None, 120, 120, 256)        0         ['lambda_4[0][0]',
#                                                                      'dropout_11[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 120, 120, 256)        65792     ['multiply_4[0][0]']
#
#  up_sampling2d_10 (UpSampli  (None, 120, 120, 512)        0         ['dropout_14[0][0]']
#  ng2D)
#
#  batch_normalization_42 (Ba  (None, 120, 120, 256)        1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  concatenate_20 (Concatenat  (None, 120, 120, 768)        0         ['up_sampling2d_10[0][0]',
#  e)                                                                  'batch_normalization_42[0][0]
#                                                                     ']
#
#  separable_conv2d_30 (Separ  (None, 120, 120, 128)        105344    ['concatenate_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_43 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_30[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  separable_conv2d_31 (Separ  (None, 120, 120, 128)        17664     ['re_lu_30[0][0]']
#  ableConv2D)
#
#  batch_normalization_44 (Ba  (None, 120, 120, 128)        512       ['separable_conv2d_31[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 120, 120, 128)        0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  concatenate_21 (Concatenat  (None, 120, 120, 256)        0         ['re_lu_30[0][0]',
#  e)                                                                  're_lu_31[0][0]']
#
#  dropout_15 (Dropout)        (None, 120, 120, 256)        0         ['concatenate_21[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 120, 120, 64)         16448     ['dropout_15[0][0]']
#
#  batch_normalization_45 (Ba  (None, 120, 120, 64)         256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 120, 120, 64)         0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 120, 120, 64)         4160      ['activation_15[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 120, 120, 64)         8256      ['dropout_10[0][0]']
#
#  add_5 (Add)                 (None, 120, 120, 64)         0         ['conv2d_31[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  activation_16 (Activation)  (None, 120, 120, 64)         0         ['add_5[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 120, 120, 1)          65        ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 120, 120, 1)          0         ['conv2d_32[0][0]']
#
#  up_sampling2d_11 (UpSampli  (None, 240, 240, 1)          0         ['activation_17[0][0]']
#  ng2D)
#
#  lambda_5 (Lambda)           (None, 240, 240, 128)        0         ['up_sampling2d_11[0][0]']
#
#  multiply_5 (Multiply)       (None, 240, 240, 128)        0         ['lambda_5[0][0]',
#                                                                      'dropout_10[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 240, 240, 128)        16512     ['multiply_5[0][0]']
#
#  up_sampling2d_12 (UpSampli  (None, 240, 240, 256)        0         ['dropout_15[0][0]']
#  ng2D)
#
#  batch_normalization_46 (Ba  (None, 240, 240, 128)        512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  concatenate_22 (Concatenat  (None, 240, 240, 384)        0         ['up_sampling2d_12[0][0]',
#  e)                                                                  'batch_normalization_46[0][0]
#                                                                     ']
#
#  separable_conv2d_32 (Separ  (None, 240, 240, 64)         28096     ['concatenate_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_47 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  separable_conv2d_33 (Separ  (None, 240, 240, 64)         4736      ['re_lu_32[0][0]']
#  ableConv2D)
#
#  batch_normalization_48 (Ba  (None, 240, 240, 64)         256       ['separable_conv2d_33[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 240, 240, 64)         0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  concatenate_23 (Concatenat  (None, 240, 240, 128)        0         ['re_lu_32[0][0]',
#  e)                                                                  're_lu_33[0][0]']
#
#  dropout_16 (Dropout)        (None, 240, 240, 128)        0         ['concatenate_23[0][0]']
#
#  tf.compat.v1.transpose_12   (None, 240, 240, 128)        0         ['dropout_16[0][0]']
#  (TFOpLambda)
#
#  tf.math.reduce_max_9 (TFOp  (None, 240, 240)             0         ['tf.compat.v1.transpose_12[0]
#  Lambda)                                                            [0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 240, 240)             0         ['tf.compat.v1.transpose_12[0]
#  pLambda)                                                           [0]']
#
#  tf.compat.v1.transpose_14   (None, 128, 240, 240)        0         ['dropout_16[0][0]']
#  (TFOpLambda)
#
#  tf.compat.v1.transpose_8 (  (None, 480, 480, 64)         0         ['dropout_9[0][0]']
#  TFOpLambda)
#
#  tf.math.reduce_max_11 (TFO  (None, 240, 240)             0         ['dropout_16[0][0]']
#  pLambda)
#
#  tf.math.reduce_mean_11 (TF  (None, 240, 240)             0         ['dropout_16[0][0]']
#  OpLambda)
#
#  tf.expand_dims_18 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_max_9[0][0]']
#  bda)
#
#  tf.expand_dims_19 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_mean_9[0][0]'
#  bda)                                                               ]
#
#  tf.math.reduce_max_10 (TFO  (None, 128, 240)             0         ['tf.compat.v1.transpose_14[0]
#  pLambda)                                                           [0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 128, 240)             0         ['tf.compat.v1.transpose_14[0]
#  OpLambda)                                                          [0]']
#
#  tf.math.reduce_max_6 (TFOp  (None, 480, 480)             0         ['tf.compat.v1.transpose_8[0][
#  Lambda)                                                            0]']
#
#  tf.math.reduce_mean_6 (TFO  (None, 480, 480)             0         ['tf.compat.v1.transpose_8[0][
#  pLambda)                                                           0]']
#
#  tf.compat.v1.transpose_10   (None, 64, 480, 480)         0         ['dropout_9[0][0]']
#  (TFOpLambda)
#
#  tf.expand_dims_22 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_max_11[0][0]'
#  bda)                                                               ]
#
#  tf.expand_dims_23 (TFOpLam  (None, 240, 240, 1)          0         ['tf.math.reduce_mean_11[0][0]
#  bda)                                                               ']
#
#  tf.concat_9 (TFOpLambda)    (None, 240, 240, 2)          0         ['tf.expand_dims_18[0][0]',
#                                                                      'tf.expand_dims_19[0][0]']
#
#  tf.expand_dims_20 (TFOpLam  (None, 128, 240, 1)          0         ['tf.math.reduce_max_10[0][0]'
#  bda)                                                               ]
#
#  tf.expand_dims_21 (TFOpLam  (None, 128, 240, 1)          0         ['tf.math.reduce_mean_10[0][0]
#  bda)                                                               ']
#
#  tf.math.reduce_max_8 (TFOp  (None, 480, 480)             0         ['dropout_9[0][0]']
#  Lambda)
#
#  tf.math.reduce_mean_8 (TFO  (None, 480, 480)             0         ['dropout_9[0][0]']
#  pLambda)
#
#  tf.expand_dims_12 (TFOpLam  (None, 480, 480, 1)          0         ['tf.math.reduce_max_6[0][0]']
#  bda)
#
#  tf.expand_dims_13 (TFOpLam  (None, 480, 480, 1)          0         ['tf.math.reduce_mean_6[0][0]'
#  bda)                                                               ]
#
#  tf.math.reduce_max_7 (TFOp  (None, 64, 480)              0         ['tf.compat.v1.transpose_10[0]
#  Lambda)                                                            [0]']
#
#  tf.math.reduce_mean_7 (TFO  (None, 64, 480)              0         ['tf.compat.v1.transpose_10[0]
#  pLambda)                                                           [0]']
#
#  tf.concat_11 (TFOpLambda)   (None, 240, 240, 2)          0         ['tf.expand_dims_22[0][0]',
#                                                                      'tf.expand_dims_23[0][0]']
#
#  conv2d_34 (Conv2D)          multiple                     18        ['tf.concat_6[0][0]',
#                                                                      'tf.concat_9[0][0]']
#
#  tf.concat_10 (TFOpLambda)   (None, 128, 240, 2)          0         ['tf.expand_dims_20[0][0]',
#                                                                      'tf.expand_dims_21[0][0]']
#
#  tf.expand_dims_16 (TFOpLam  (None, 480, 480, 1)          0         ['tf.math.reduce_max_8[0][0]']
#  bda)
#
#  tf.expand_dims_17 (TFOpLam  (None, 480, 480, 1)          0         ['tf.math.reduce_mean_8[0][0]'
#  bda)                                                               ]
#
#  tf.concat_6 (TFOpLambda)    (None, 480, 480, 2)          0         ['tf.expand_dims_12[0][0]',
#                                                                      'tf.expand_dims_13[0][0]']
#
#  tf.expand_dims_14 (TFOpLam  (None, 64, 480, 1)           0         ['tf.math.reduce_max_7[0][0]']
#  bda)
#
#  tf.expand_dims_15 (TFOpLam  (None, 64, 480, 1)           0         ['tf.math.reduce_mean_7[0][0]'
#  bda)                                                               ]
#
#  conv2d_36 (Conv2D)          multiple                     18        ['tf.concat_8[0][0]',
#                                                                      'tf.concat_11[0][0]']
#
#  batch_normalization_49 (Ba  multiple                     4         ['conv2d_34[0][0]',
#  tchNormalization)                                                   'conv2d_34[1][0]']
#
#  conv2d_35 (Conv2D)          multiple                     18        ['tf.concat_7[0][0]',
#                                                                      'tf.concat_10[0][0]']
#
#  tf.concat_8 (TFOpLambda)    (None, 480, 480, 2)          0         ['tf.expand_dims_16[0][0]',
#                                                                      'tf.expand_dims_17[0][0]']
#
#  tf.concat_7 (TFOpLambda)    (None, 64, 480, 2)           0         ['tf.expand_dims_14[0][0]',
#                                                                      'tf.expand_dims_15[0][0]']
#
#  batch_normalization_51 (Ba  multiple                     4         ['conv2d_36[0][0]',
#  tchNormalization)                                                   'conv2d_36[1][0]']
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 240, 240, 1)          0         ['batch_normalization_49[1][0]
#                                                                     ']
#
#  batch_normalization_50 (Ba  multiple                     4         ['conv2d_35[0][0]',
#  tchNormalization)                                                   'conv2d_35[1][0]']
#
#  tf.nn.relu_11 (TFOpLambda)  (None, 240, 240, 1)          0         ['batch_normalization_51[1][0]
#                                                                     ']
#
#  tf.math.sigmoid_9 (TFOpLam  (None, 240, 240, 1)          0         ['tf.nn.relu_9[0][0]']
#  bda)
#
#  tf.nn.relu_10 (TFOpLambda)  (None, 128, 240, 1)          0         ['batch_normalization_50[1][0]
#                                                                     ']
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 480, 480, 1)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  tf.math.sigmoid_11 (TFOpLa  (None, 240, 240, 1)          0         ['tf.nn.relu_11[0][0]']
#  mbda)
#
#  tf.math.multiply_12 (TFOpL  (None, 240, 240, 128)        0         ['tf.compat.v1.transpose_12[0]
#  ambda)                                                             [0]',
#                                                                      'tf.math.sigmoid_9[0][0]']
#
#  tf.math.sigmoid_10 (TFOpLa  (None, 128, 240, 1)          0         ['tf.nn.relu_10[0][0]']
#  mbda)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 480, 480, 1)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  tf.math.sigmoid_6 (TFOpLam  (None, 480, 480, 1)          0         ['tf.nn.relu_6[0][0]']
#  bda)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 64, 480, 1)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  tf.math.multiply_14 (TFOpL  (None, 240, 240, 128)        0         ['dropout_16[0][0]',
#  ambda)                                                              'tf.math.sigmoid_11[0][0]']
#
#  tf.compat.v1.transpose_13   (None, 240, 240, 128)        0         ['tf.math.multiply_12[0][0]']
#  (TFOpLambda)
#
#  tf.math.multiply_13 (TFOpL  (None, 128, 240, 240)        0         ['tf.compat.v1.transpose_14[0]
#  ambda)                                                             [0]',
#                                                                      'tf.math.sigmoid_10[0][0]']
#
#  tf.math.sigmoid_8 (TFOpLam  (None, 480, 480, 1)          0         ['tf.nn.relu_8[0][0]']
#  bda)
#
#  tf.math.multiply_8 (TFOpLa  (None, 480, 480, 64)         0         ['tf.compat.v1.transpose_8[0][
#  mbda)                                                              0]',
#                                                                      'tf.math.sigmoid_6[0][0]']
#
#  tf.math.sigmoid_7 (TFOpLam  (None, 64, 480, 1)           0         ['tf.nn.relu_7[0][0]']
#  bda)
#
#  tf.__operators__.add_6 (TF  (None, 240, 240, 128)        0         ['tf.math.multiply_14[0][0]',
#  OpLambda)                                                           'tf.compat.v1.transpose_13[0]
#                                                                     [0]']
#
#  tf.compat.v1.transpose_15   (None, 240, 240, 128)        0         ['tf.math.multiply_13[0][0]']
#  (TFOpLambda)
#
#  tf.math.multiply_10 (TFOpL  (None, 480, 480, 64)         0         ['dropout_9[0][0]',
#  ambda)                                                              'tf.math.sigmoid_8[0][0]']
#
#  tf.compat.v1.transpose_9 (  (None, 480, 480, 64)         0         ['tf.math.multiply_8[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_9 (TFOpLa  (None, 64, 480, 480)         0         ['tf.compat.v1.transpose_10[0]
#  mbda)                                                              [0]',
#                                                                      'tf.math.sigmoid_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 240, 240, 128)        0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.compat.v1.transpose_15[0]
#                                                                     [0]']
#
#  tf.__operators__.add_4 (TF  (None, 480, 480, 64)         0         ['tf.math.multiply_10[0][0]',
#  OpLambda)                                                           'tf.compat.v1.transpose_9[0][
#                                                                     0]']
#
#  tf.compat.v1.transpose_11   (None, 480, 480, 64)         0         ['tf.math.multiply_9[0][0]']
#  (TFOpLambda)
#
#  tf.math.multiply_15 (TFOpL  (None, 240, 240, 128)        0         ['tf.__operators__.add_7[0][0]
#  ambda)                                                             ']
#
#  tf.__operators__.add_5 (TF  (None, 480, 480, 64)         0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.compat.v1.transpose_11[0]
#                                                                     [0]']
#
#  up_sampling2d_13 (UpSampli  (None, 480, 480, 128)        0         ['tf.math.multiply_15[0][0]']
#  ng2D)
#
#  tf.math.multiply_11 (TFOpL  (None, 480, 480, 64)         0         ['tf.__operators__.add_5[0][0]
#  ambda)                                                             ']
#
#  concatenate_24 (Concatenat  (None, 480, 480, 192)        0         ['up_sampling2d_13[0][0]',
#  e)                                                                  'tf.math.multiply_11[0][0]']
#
#  separable_conv2d_34 (Separ  (None, 480, 480, 32)         7904      ['concatenate_24[0][0]']
#  ableConv2D)
#
#  batch_normalization_52 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  separable_conv2d_35 (Separ  (None, 480, 480, 32)         1344      ['re_lu_34[0][0]']
#  ableConv2D)
#
#  batch_normalization_53 (Ba  (None, 480, 480, 32)         128       ['separable_conv2d_35[0][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 480, 480, 32)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  concatenate_25 (Concatenat  (None, 480, 480, 64)         0         ['re_lu_34[0][0]',
#  e)                                                                  're_lu_35[0][0]']
#
#  dropout_17 (Dropout)        (None, 480, 480, 64)         0         ['concatenate_25[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 480, 480, 4)          260       ['dropout_17[0][0]']
#
# ==================================================================================================
# Total params: 2323844 (8.86 MB)
# Trainable params: 2315262 (8.83 MB)
# Non-trainable params: 8582 (33.52 KB)
# __________________________________________________________________________________________________
# (None, 480, 480, 3)

# %%
# train_img_gen.reset()
# val_img_gen.reset()

history=model.fit(train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=50,
          verbose=1,
          validation_data=val_img_gen,
          validation_steps=val_steps_per_epoch)


###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 30/30 [==============================] - 198s 6s/step - loss: 1.1543 - accuracy: 0.5399 - jacard_coef: 0.2651 - val_loss: 1.3525 - val_accuracy: 0.4126 - val_jacard_coef: 0.1490
# Epoch 2/50
# 30/30 [==============================] - 36s 1s/step - loss: 0.8236 - accuracy: 0.6940 - jacard_coef: 0.4048 - val_loss: 1.3156 - val_accuracy: 0.4273 - val_jacard_coef: 0.1553
# Epoch 3/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.7931 - accuracy: 0.6760 - jacard_coef: 0.4208 - val_loss: 1.2830 - val_accuracy: 0.4328 - val_jacard_coef: 0.1632
# Epoch 4/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.7099 - accuracy: 0.7091 - jacard_coef: 0.4355 - val_loss: 1.2651 - val_accuracy: 0.3622 - val_jacard_coef: 0.1650
# Epoch 5/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.7156 - accuracy: 0.7259 - jacard_coef: 0.4556 - val_loss: 1.2446 - val_accuracy: 0.4030 - val_jacard_coef: 0.1725
# Epoch 6/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.7085 - accuracy: 0.7098 - jacard_coef: 0.4453 - val_loss: 1.1833 - val_accuracy: 0.4721 - val_jacard_coef: 0.1883
# Epoch 7/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.6990 - accuracy: 0.7296 - jacard_coef: 0.4500 - val_loss: 1.1893 - val_accuracy: 0.3650 - val_jacard_coef: 0.1878
# Epoch 8/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6482 - accuracy: 0.7436 - jacard_coef: 0.4812 - val_loss: 1.1582 - val_accuracy: 0.4095 - val_jacard_coef: 0.1981
# Epoch 9/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6406 - accuracy: 0.7482 - jacard_coef: 0.4967 - val_loss: 1.1283 - val_accuracy: 0.4017 - val_jacard_coef: 0.2161
# Epoch 10/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6964 - accuracy: 0.7086 - jacard_coef: 0.4525 - val_loss: 1.0811 - val_accuracy: 0.3916 - val_jacard_coef: 0.2247
# Epoch 11/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6147 - accuracy: 0.7411 - jacard_coef: 0.4847 - val_loss: 1.0756 - val_accuracy: 0.3824 - val_jacard_coef: 0.2464
# Epoch 12/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5654 - accuracy: 0.7746 - jacard_coef: 0.5236 - val_loss: 0.9754 - val_accuracy: 0.5301 - val_jacard_coef: 0.2656
# Epoch 13/50
# 30/30 [==============================] - 36s 1s/step - loss: 0.5972 - accuracy: 0.7589 - jacard_coef: 0.5068 - val_loss: 1.0244 - val_accuracy: 0.4915 - val_jacard_coef: 0.2827
# Epoch 14/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6758 - accuracy: 0.7285 - jacard_coef: 0.4731 - val_loss: 0.9287 - val_accuracy: 0.5471 - val_jacard_coef: 0.3189
# Epoch 15/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.6221 - accuracy: 0.7573 - jacard_coef: 0.5015 - val_loss: 0.8924 - val_accuracy: 0.5676 - val_jacard_coef: 0.3383
# Epoch 16/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5699 - accuracy: 0.7863 - jacard_coef: 0.5161 - val_loss: 0.8944 - val_accuracy: 0.5460 - val_jacard_coef: 0.3634
# Epoch 17/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.6262 - accuracy: 0.7512 - jacard_coef: 0.4983 - val_loss: 0.9813 - val_accuracy: 0.5331 - val_jacard_coef: 0.3393
# Epoch 18/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5752 - accuracy: 0.7779 - jacard_coef: 0.5174 - val_loss: 0.6843 - val_accuracy: 0.7045 - val_jacard_coef: 0.4502
# Epoch 19/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5715 - accuracy: 0.7743 - jacard_coef: 0.5275 - val_loss: 0.9536 - val_accuracy: 0.5756 - val_jacard_coef: 0.4177
# Epoch 20/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.6020 - accuracy: 0.7607 - jacard_coef: 0.5065 - val_loss: 0.6723 - val_accuracy: 0.7043 - val_jacard_coef: 0.4709
# Epoch 21/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5380 - accuracy: 0.7944 - jacard_coef: 0.5363 - val_loss: 0.7176 - val_accuracy: 0.7188 - val_jacard_coef: 0.5113
# Epoch 22/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5566 - accuracy: 0.7934 - jacard_coef: 0.5448 - val_loss: 0.5939 - val_accuracy: 0.8116 - val_jacard_coef: 0.5659
# Epoch 23/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5989 - accuracy: 0.7681 - jacard_coef: 0.5116 - val_loss: 0.5105 - val_accuracy: 0.8149 - val_jacard_coef: 0.5667
# Epoch 24/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5023 - accuracy: 0.8178 - jacard_coef: 0.5682 - val_loss: 0.4970 - val_accuracy: 0.7824 - val_jacard_coef: 0.5475
# Epoch 25/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5086 - accuracy: 0.8124 - jacard_coef: 0.5554 - val_loss: 1.1276 - val_accuracy: 0.6264 - val_jacard_coef: 0.4141
# Epoch 26/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5319 - accuracy: 0.7965 - jacard_coef: 0.5532 - val_loss: 0.6391 - val_accuracy: 0.7621 - val_jacard_coef: 0.5419
# Epoch 27/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.4975 - accuracy: 0.8158 - jacard_coef: 0.5619 - val_loss: 0.8955 - val_accuracy: 0.6976 - val_jacard_coef: 0.4691
# Epoch 28/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5220 - accuracy: 0.7882 - jacard_coef: 0.5544 - val_loss: 0.8074 - val_accuracy: 0.6449 - val_jacard_coef: 0.4500
# Epoch 29/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5561 - accuracy: 0.7740 - jacard_coef: 0.5438 - val_loss: 0.5141 - val_accuracy: 0.7903 - val_jacard_coef: 0.5722
# Epoch 30/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5295 - accuracy: 0.8024 - jacard_coef: 0.5579 - val_loss: 0.6028 - val_accuracy: 0.7811 - val_jacard_coef: 0.5705
# Epoch 31/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5149 - accuracy: 0.8059 - jacard_coef: 0.5655 - val_loss: 0.4665 - val_accuracy: 0.8289 - val_jacard_coef: 0.5772
# Epoch 32/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5229 - accuracy: 0.7966 - jacard_coef: 0.5330 - val_loss: 0.6605 - val_accuracy: 0.7446 - val_jacard_coef: 0.5546
# Epoch 33/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5104 - accuracy: 0.8175 - jacard_coef: 0.5756 - val_loss: 0.5864 - val_accuracy: 0.7783 - val_jacard_coef: 0.5288
# Epoch 34/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.5398 - accuracy: 0.7874 - jacard_coef: 0.5413 - val_loss: 0.5826 - val_accuracy: 0.8085 - val_jacard_coef: 0.5920
# Epoch 35/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4717 - accuracy: 0.8268 - jacard_coef: 0.5781 - val_loss: 0.7076 - val_accuracy: 0.7636 - val_jacard_coef: 0.5757
# Epoch 36/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4177 - accuracy: 0.8454 - jacard_coef: 0.6123 - val_loss: 0.5434 - val_accuracy: 0.7819 - val_jacard_coef: 0.5802
# Epoch 37/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.5067 - accuracy: 0.8120 - jacard_coef: 0.5805 - val_loss: 0.9376 - val_accuracy: 0.6900 - val_jacard_coef: 0.4870
# Epoch 38/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.3970 - accuracy: 0.8478 - jacard_coef: 0.6205 - val_loss: 0.5616 - val_accuracy: 0.7877 - val_jacard_coef: 0.6031
# Epoch 39/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.4387 - accuracy: 0.8343 - jacard_coef: 0.6037 - val_loss: 0.7414 - val_accuracy: 0.7224 - val_jacard_coef: 0.5294
# Epoch 40/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4783 - accuracy: 0.8205 - jacard_coef: 0.5828 - val_loss: 0.8038 - val_accuracy: 0.7015 - val_jacard_coef: 0.5102
# Epoch 41/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.3926 - accuracy: 0.8511 - jacard_coef: 0.6227 - val_loss: 0.7088 - val_accuracy: 0.7360 - val_jacard_coef: 0.5294
# Epoch 42/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.4024 - accuracy: 0.8449 - jacard_coef: 0.6279 - val_loss: 0.3303 - val_accuracy: 0.8684 - val_jacard_coef: 0.7021
# Epoch 43/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4228 - accuracy: 0.8426 - jacard_coef: 0.6168 - val_loss: 0.6934 - val_accuracy: 0.7438 - val_jacard_coef: 0.5909
# Epoch 44/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4304 - accuracy: 0.8391 - jacard_coef: 0.6168 - val_loss: 0.5484 - val_accuracy: 0.7947 - val_jacard_coef: 0.6040
# Epoch 45/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.4807 - accuracy: 0.8160 - jacard_coef: 0.5961 - val_loss: 0.4356 - val_accuracy: 0.8424 - val_jacard_coef: 0.6379
# Epoch 46/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.3622 - accuracy: 0.8667 - jacard_coef: 0.6523 - val_loss: 0.7135 - val_accuracy: 0.7506 - val_jacard_coef: 0.5709
# Epoch 47/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.3999 - accuracy: 0.8572 - jacard_coef: 0.6453 - val_loss: 0.5397 - val_accuracy: 0.8074 - val_jacard_coef: 0.6193
# Epoch 48/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.3418 - accuracy: 0.8739 - jacard_coef: 0.6650 - val_loss: 0.4572 - val_accuracy: 0.8360 - val_jacard_coef: 0.6497
# Epoch 49/50
# 30/30 [==============================] - 34s 1s/step - loss: 0.4468 - accuracy: 0.8343 - jacard_coef: 0.6070 - val_loss: 0.4294 - val_accuracy: 0.8399 - val_jacard_coef: 0.6402
# Epoch 50/50
# 30/30 [==============================] - 35s 1s/step - loss: 0.3575 - accuracy: 0.8812 - jacard_coef: 0.6687 - val_loss: 0.4469 - val_accuracy: 0.8280 - val_jacard_coef: 0.6418

# %%
model.save('LW.hdf5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model

model = load_model("LW.hdf5", compile=False)

# %%
test_image_batch, test_mask_batch = val_img_gen.__next__()

#Convert categorical to integer for visualization and IoU calculation
test_mask_batch_argmax = np.argmax(test_mask_batch, axis=3)
test_pred_batch = model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=3)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 11s 11s/step
# Mean IoU = 0.86431895

# %%
#To calculate I0U for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
print(values)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0]+ values[2,0]+ values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1]+ values[2,1]+ values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2]+ values[1,2]+ values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3]+ values[1,3]+ values[2,3])

print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)
print("IoU for class3 is: ", class3_IoU)
print("IoU for class4 is: ", class4_IoU)
# Out:
# [[1.28259e+05 6.00000e+01 8.55000e+02 2.47000e+02]
#  [8.83600e+03 1.86448e+05 3.07600e+03 1.80490e+04]
#  [3.94000e+02 1.04000e+02 3.02500e+03 0.00000e+00]
#  [4.39990e+04 1.69000e+03 6.49300e+03 5.20065e+05]]
# IoU for class1 is:  0.70221186
# IoU for class2 is:  0.8542355
# IoU for class3 is:  0.21689253
# IoU for class4 is:  0.8806556

# %%
img_num = random.randint(0, test_image_batch.shape[0]-1)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_image_batch[img_num])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_batch_argmax[img_num])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_pred_batch_argmax[img_num])
plt.show()

# %%
"""

Original code is from the following source. It comes with MIT License so please mention
the original reference when sharing.

The original code has been modified to fix a couple of bugs and chunks of code
unnecessary for smooth tiling are removed.

# MIT License
# Copyright (c) 2017 Vooban Inc.
# Coded by: Guillaume Chevalier
# Source to original code and license:
#     https://github.com/Vooban/Smoothly-Blend-Image-Patches
#     https://github.com/Vooban/Smoothly-Blend-Image-Patches/blob/master/LICENSE

"""
"""Perform smooth predictions on an image from tiled prediction patches."""


import numpy as np
import scipy.signal
from tqdm import tqdm

import gc


if __name__ == '__main__':
    import matplotlib.pyplot as plt
    PLOT_PROGRESS = True
    # See end of file for the rest of the __main__.
else:
    PLOT_PROGRESS = False


def _spline_window(window_size, power=2):
    """
    Squared spline (power=2) window function:
    https://www.wolframalpha.com/input/?i=y%3Dx**2,+y%3D-(x-2)**2+%2B2,+y%3D(x-4)**2,+from+y+%3D+0+to+2
    """
    intersection = int(window_size/4)
    wind_outer = (abs(2*(scipy.signal.triang(window_size))) ** power)/2
    wind_outer[intersection:-intersection] = 0

    wind_inner = 1 - (abs(2*(scipy.signal.triang(window_size) - 1)) ** power)/2
    wind_inner[:intersection] = 0
    wind_inner[-intersection:] = 0

    wind = wind_inner + wind_outer
    wind = wind / np.average(wind)
    return wind


cached_2d_windows = dict()
def _window_2D(window_size, power=2):
    """
    Make a 1D window function, then infer and return a 2D window function.
    Done with an augmentation, and self multiplication with its transpose.
    Could be generalized to more dimensions.
    """
    # Memoization
    global cached_2d_windows
    key = "{}_{}".format(window_size, power)
    if key in cached_2d_windows:
        wind = cached_2d_windows[key]
    else:
        wind = _spline_window(window_size, power)
        wind = np.expand_dims(np.expand_dims(wind, 1), 1)      #SREENI: Changed from 3, 3, to 1, 1
        wind = wind * wind.transpose(1, 0, 2)
        if PLOT_PROGRESS:
            # For demo purpose, let's look once at the window:
            plt.imshow(wind[:, :, 0], cmap="viridis")
            plt.title("2D Windowing Function for a Smooth Blending of "
                      "Overlapping Patches")
            plt.show()
        cached_2d_windows[key] = wind
    return wind


def _pad_img(img, window_size, subdivisions):
    """
    Add borders to img for a "valid" border pattern according to "window_size" and
    "subdivisions".
    Image is an np array of shape (x, y, nb_channels).
    """
    aug = int(round(window_size * (1 - 1.0/subdivisions)))
    more_borders = ((aug, aug), (aug, aug), (0, 0))
    ret = np.pad(img, pad_width=more_borders, mode='reflect')
    # gc.collect()

    if PLOT_PROGRESS:
        # For demo purpose, let's look once at the window:
        plt.imshow(ret)
        plt.title("Padded Image for Using Tiled Prediction Patches\n"
                  "(notice the reflection effect on the padded borders)")
        plt.show()
    return ret


def _unpad_img(padded_img, window_size, subdivisions):
    """
    Undo what's done in the `_pad_img` function.
    Image is an np array of shape (x, y, nb_channels).
    """
    aug = int(round(window_size * (1 - 1.0/subdivisions)))
    ret = padded_img[
        aug:-aug,
        aug:-aug,
        :
    ]
    # gc.collect()
    return ret


def _rotate_mirror_do(im):
    """
    Duplicate an np array (image) of shape (x, y, nb_channels) 8 times, in order
    to have all the possible rotations and mirrors of that image that fits the
    possible 90 degrees rotations.
    It is the D_4 (D4) Dihedral group:
    https://en.wikipedia.org/wiki/Dihedral_group
    """
    mirrs = []
    mirrs.append(np.array(im))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=1))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=2))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=3))
    im = np.array(im)[:, ::-1]
    mirrs.append(np.array(im))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=1))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=2))
    mirrs.append(np.rot90(np.array(im), axes=(0, 1), k=3))
    return mirrs


def _rotate_mirror_undo(im_mirrs):

    origs = []
    origs.append(np.array(im_mirrs[0]))
    origs.append(np.rot90(np.array(im_mirrs[1]), axes=(0, 1), k=3))
    origs.append(np.rot90(np.array(im_mirrs[2]), axes=(0, 1), k=2))
    origs.append(np.rot90(np.array(im_mirrs[3]), axes=(0, 1), k=1))
    origs.append(np.array(im_mirrs[4])[:, ::-1])
    origs.append(np.rot90(np.array(im_mirrs[5]), axes=(0, 1), k=3)[:, ::-1])
    origs.append(np.rot90(np.array(im_mirrs[6]), axes=(0, 1), k=2)[:, ::-1])
    origs.append(np.rot90(np.array(im_mirrs[7]), axes=(0, 1), k=1)[:, ::-1])
    return np.mean(origs, axis=0)


def _windowed_subdivs(padded_img, window_size, subdivisions, nb_classes, pred_func):

    WINDOW_SPLINE_2D = _window_2D(window_size=window_size, power=2)

    step = int(window_size/subdivisions)
    padx_len = padded_img.shape[0]
    pady_len = padded_img.shape[1]
    subdivs = []

    for i in range(0, padx_len-window_size+1, step):
        subdivs.append([])
        for j in range(0, pady_len-window_size+1, step):            #SREENI: Changed padx to pady (Bug in original code)
            patch = padded_img[i:i+window_size, j:j+window_size, :]
            subdivs[-1].append(patch)

    # Here, `gc.collect()` clears RAM between operations.
    # It should run faster if they are removed, if enough memory is available.
    gc.collect()
    subdivs = np.array(subdivs)
    gc.collect()
    a, b, c, d, e = subdivs.shape
    subdivs = subdivs.reshape(a * b, c, d, e)
    gc.collect()

    subdivs = pred_func(subdivs)
    gc.collect()
    subdivs = np.array([patch * WINDOW_SPLINE_2D for patch in subdivs])
    gc.collect()

    # Such 5D array:
    subdivs = subdivs.reshape(a, b, c, d, nb_classes)
    gc.collect()

    return subdivs


def _recreate_from_subdivs(subdivs, window_size, subdivisions, padded_out_shape):
    """
    Merge tiled overlapping patches smoothly.
    """
    step = int(window_size/subdivisions)
    padx_len = padded_out_shape[0]
    pady_len = padded_out_shape[1]

    y = np.zeros(padded_out_shape)

    a = 0
    for i in range(0, padx_len-window_size+1, step):
        b = 0
        for j in range(0, pady_len-window_size+1, step):                #SREENI: Changed padx to pady (Bug in original code)
            windowed_patch = subdivs[a, b]
            y[i:i+window_size, j:j+window_size] = y[i:i+window_size, j:j+window_size] + windowed_patch
            b += 1
        a += 1
    return y / (subdivisions ** 2)


def predict_img_with_smooth_windowing(input_img, window_size, subdivisions, nb_classes, pred_func):

    pad = _pad_img(input_img, window_size, subdivisions)
    pads = _rotate_mirror_do(pad)


    res = []
    for pad in tqdm(pads):
        # For every rotation:
        sd = _windowed_subdivs(pad, window_size, subdivisions, nb_classes, pred_func)
        one_padded_result = _recreate_from_subdivs(
            sd, window_size, subdivisions,
            padded_out_shape=list(pad.shape[:-1])+[nb_classes])

        res.append(one_padded_result)

    # Merge after rotations:
    padded_results = _rotate_mirror_undo(res)

    prd = _unpad_img(padded_results, window_size, subdivisions)

    prd = prd[:input_img.shape[0], :input_img.shape[1], :]

    if PLOT_PROGRESS:
        plt.imshow(prd)
        plt.title("Smoothly Merged Patches that were Tiled Tighter")
        plt.show()
    return prd

# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import segmentation_models as sm

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# from smooth_tiled_predictions import predict_img_with_smooth_windowing



img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/val/images/NITR_AC_100.png")
input_img = scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)
input_img = preprocess_input(input_img)

original_mask = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/val/gray_masks/NITR_AC_100.png")
# original_mask = original_mask[:,:,0]  #Use only single channel...
original_mask = to_categorical(original_mask, num_classes=n_classes)

from keras.models import load_model
model = load_model("LW.hdf5", compile=False)

# size of patches
patch_size = 480

# Number of classes
n_classes = 4


###################################################################################
#Predict using smooth blending

# Use the algorithm. The `pred_func` is passed and will process all the image 8-fold by tiling small patches with overlap, called once with all those image as a batch outer dimension.
# Note that model.predict(...) accepts a 4D tensor of shape (batch, x, y, nb_channels), such as a Keras model.
predictions_smooth = predict_img_with_smooth_windowing(
    input_img,
    window_size=patch_size,
    subdivisions=2,  # Minimal amount of overlap for windowing. Must be an even number.
    nb_classes=n_classes,
    pred_func=(
        lambda img_batch_subdiv: model.predict((img_batch_subdiv))
    )
)


final_prediction = np.argmax(predictions_smooth, axis=2)

#Save prediction and original mask for comparison
plt.imsave('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/segmented.jpg', final_prediction)
plt.imsave('/content/drive/MyDrive/Colab Notebooks/Lw-SegNet/data/mask.jpg', original_mask)
###################



plt.figure(figsize=(12, 12))
plt.subplot(221)
plt.title('Testing Image')
plt.imshow(img)
plt.subplot(222)
plt.title('Testing Label')
# Convert one-hot encoded mask to a displayable format
plt.imshow(np.argmax(original_mask, axis=-1))  # Select the channel with the highest value
plt.subplot(223)
plt.title('Prediction with smooth blending')
plt.imshow(final_prediction)
plt.show()


#############################
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# 1/1 [==============================] - 69s 69s/step
#  12%|█▎        | 1/8 [01:11<08:20, 71.46s/it]
# 1/1 [==============================] - 67s 67s/step
#  25%|██▌       | 2/8 [02:35<07:53, 78.98s/it]
# 1/1 [==============================] - 67s 67s/step
#  38%|███▊      | 3/8 [03:59<06:46, 81.35s/it]
# 1/1 [==============================] - 66s 66s/step
#  50%|█████     | 4/8 [05:24<05:29, 82.47s/it]
# 1/1 [==============================] - 66s 66s/step
#  62%|██████▎   | 5/8 [06:48<04:09, 83.06s/it]
# 1/1 [==============================] - 66s 66s/step
#  75%|███████▌  | 6/8 [08:12<02:46, 83.45s/it]
# 1/1 [==============================] - 66s 66s/step
#  88%|████████▊ | 7/8 [09:36<01:23, 83.68s/it]
# 1/1 [==============================] - 67s 67s/step
# 100%|██████████| 8/8 [10:45<00:00, 80.72s/it]
